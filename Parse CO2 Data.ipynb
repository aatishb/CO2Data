# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Mauna Loa Observatory Data (Keeling Curve)
# ### Used for 1959 - 2019
# Data accessed from https://library.ucsd.edu/dc/object/bb3859642r

# %%
df = pd.read_csv ('Mauna Loa Observatory (present day - 1959).csv', na_values=-99.99, skipinitialspace = True)
annualMean = df.groupby('Yr').mean()
annualMean
# Out:
#        Mn          Date       DateYr   CO2 (ppm)  \
# Yr
# 1958  6.5  21366.500000  1958.497258  315.332500
# 1959  6.5  21731.500000  1959.497258  315.981667
# 1960  6.5  22097.333333  1960.498192  316.910000
# 1961  6.5  22462.500000  1961.497258  317.644167
# 1962  6.5  22827.500000  1962.497258  318.454167
# 1963  6.5  23192.500000  1963.497258  318.992500
# 1964  6.5  23558.333333  1964.498192  319.202222
# 1965  6.5  23923.500000  1965.497258  320.036667
# 1966  6.5  24288.500000  1966.497258  321.369167
# 1967  6.5  24653.500000  1967.497258  322.180833
# 1968  6.5  25019.333333  1968.498192  323.050000
# 1969  6.5  25384.500000  1969.497258  324.622500
# 1970  6.5  25749.500000  1970.497258  325.681667
# 1971  6.5  26114.500000  1971.497258  326.320000
# 1972  6.5  26480.333333  1972.498192  327.456667
# 1973  6.5  26845.500000  1973.497258  329.677500
# 1974  6.5  27210.500000  1974.497258  330.244167
# 1975  6.5  27575.500000  1975.497258  331.152500
# ...

# %%
ax = plt.gca()

for yax in ['CO2 (ppm)', 'CO2 (ppm) seasonally adjusted', 'CO2 (ppm) fit', 'CO2 (ppm)  seasonally adjusted fit','CO2 (ppm) filled', 'CO2 (ppm) seasonally adjusted filled']:
    annualMean.plot(y = yax, figsize=(15,10), ax=ax)

plt.show()

# %%
exportData1 = annualMean[['CO2 (ppm)']][1:-1].rename(columns = {'CO2 (ppm)':'CO2'})
exportData1.index.names = ['YearAD']
exportData1
# Out:
#                CO2
# YearAD
# 1959    315.981667
# 1960    316.910000
# 1961    317.644167
# 1962    318.454167
# 1963    318.992500
# 1964    319.202222
# 1965    320.036667
# 1966    321.369167
# 1967    322.180833
# 1968    323.050000
# 1969    324.622500
# 1970    325.681667
# 1971    326.320000
# 1972    327.456667
# 1973    329.677500
# 1974    330.244167
# 1975    331.152500
# 1976    332.151667
# 1977    333.900833
# 1978    335.505000
# 1979    336.850833
# 1980    338.684167
# 1981    339.933333
# 1982    341.131667
# 1983    342.781667
# 1984    344.420833
# 1985    345.902500
# 1986    347.153333
# 1987    348.933333
# 1988    351.485000
# ...            ...
# 1990    354.185833
# 1991    355.590833
# 1992    356.373333
# 1993    357.041667
# 1994    358.885833
# 1995    360.875833
# 1996    362.640833
# 1997    363.763333
# 1998    366.630000
# 1999    368.312500
# 2000    369.475000
# 2001    371.019167
# 2002    373.095833
# 2003    375.636667
# 2004    377.363333
# ...

# %% [markdown]
# # Law Dome Ice Core Data
# ### Used for 1 - 1958
# Data accessed from https://www.ncdc.noaa.gov/paleo-search/study/9959

# %%
df = pd.read_csv('Law Dome Ice Core 2000 Year (1 - 2004).txt', delim_whitespace=True)
df.plot(x = 'YearAD', y='CO2spl',figsize=(15,10))
plt.show()

# %%
exportData2 = df[['YearAD', 'CO2spl']].set_index('YearAD')[0:-46].rename(columns = {'CO2spl':'CO2'})
exportData2
# Out:
#           CO2
# YearAD
# 1       276.7
# 2       276.8
# 3       276.8
# 4       276.9
# 5       276.9
# 6       277.0
# 7       277.1
# 8       277.1
# 9       277.2
# 10      277.2
# 11      277.3
# 12      277.3
# 13      277.4
# 14      277.4
# 15      277.5
# 16      277.5
# 17      277.6
# 18      277.6
# 19      277.6
# 20      277.7
# 21      277.7
# 22      277.7
# 23      277.8
# 24      277.8
# 25      277.8
# 26      277.9
# 27      277.9
# 28      277.9
# 29      277.9
# 30      277.9
# ...       ...
# 1929    306.2
# 1930    306.6
# 1931    307.0
# 1932    307.3
# 1933    307.6
# 1934    308.0
# 1935    308.4
# 1936    308.7
# 1937    309.2
# 1938    309.6
# 1939    310.1
# 1940    310.5
# 1941    310.8
# 1942    311.0
# 1943    311.0
# 1944    311.0
# 1945    310.9
# 1946    310.8
# 1947    310.8
# 1948    310.9
# 1949    311.0
# 1950    311.2
# 1951    311.5
# 1952    311.8
# 1953    312.2
# 1954    312.8
# 1955    313.5
# 1956    314.1
# 1957    314.7
# ...

# %%
ax = plt.gca()

exportData1.plot(figsize=(15,10), ax=ax)
exportData2.plot(figsize=(15,10), ax=ax)

plt.show()

# %% [markdown]
# # Ice Core 8000KYr
# ### Used for past 800 thousand years until year -1
# Data accessed from https://www.ncdc.noaa.gov/paleo-search/study/6091

# %%
df = pd.read_csv ('Ice Core 8000KYr (1813 - 800KYr).txt', delim_whitespace=True)
df['YearAD'] = 1950 - df['Age(yrBP)']
exportData3 = df.set_index('YearAD')[['CO2(ppmv)']][21:].rename(columns = {'CO2(ppmv)':'CO2'})
exportData3
# Out:
#            CO2
# YearAD
# -107     276.7
# -178     276.7
# -262     277.6
# -384     277.9
# -483     273.9
# -586     278.9
# -654     275.3
# -778     274.7
# -856     276.3
# -952     274.6
# -1103    276.3
# -1166    273.1
# -1265    274.0
# -1386    275.0
# -1503    273.4
# -1573    273.0
# -1672    271.5
# -1771    275.4
# -1840    274.9
# -1960    271.7
# -2054    271.6
# -2146    272.8
# -2211    271.5
# -2374    271.1
# -2424    269.1
# -2530    269.8
# -2623    271.5
# -2753    270.7
# -2816    269.3
# -2924    268.6
# ...        ...
# -775606  246.3
# -775950  246.1
# -776848  245.8
# -777414  243.9
# -778318  248.5
# -778662  242.8
# -779585  248.7
# -780109  246.2
# -781313  252.1
# -782197  246.9
# -782742  250.7
# -783463  253.3
# -783839  255.4
# -784637  260.3
# -785126  256.9
# -785855  248.1
# -786083  247.9
# -786937  229.5
# -787431  226.3
# -788203  218.2
# -788588  221.3
# -789541  215.4
# -790131  205.1
# -790993  204.0
# -791310  209.0
# -792658  199.4
# ...

# %%
ax = plt.gca()

exportData1.plot(figsize=(15,10), ax=ax)
exportData2.plot(figsize=(15,10), ax=ax)
exportData3.plot(figsize=(15,10), ax=ax)

ax.set_xlim(-800000,2000)
plt.show()

# %%
exportData = pd.concat([exportData1, exportData2, exportData3]).sort_index(ascending = False)
exportData['YearsBefore2019'] = 2019 - exportData.index
exportData
# Out:
#                 CO2  YearsBefore2019
# YearAD
#  2019    411.494167                0
#  2018    408.587500                1
#  2017    406.585000                2
#  2016    404.277500                3
#  2015    400.885000                4
#  2014    398.614167                5
#  2013    396.566667                6
#  2012    393.870000                7
#  2011    391.648333                8
#  2010    389.900000                9
#  2009    387.360000               10
#  2008    385.449167               11
#  2007    383.592500               12
#  2006    381.807500               13
#  2005    379.601667               14
#  2004    377.363333               15
#  2003    375.636667               16
#  2002    373.095833               17
#  2001    371.019167               18
#  2000    369.475000               19
#  1999    368.312500               20
#  1998    366.630000               21
#  1997    363.763333               22
#  1996    362.640833               23
# ...

# %%
exportData.plot(y = 'CO2', figsize=(15,10), xlim=[10000,-800000])
plt.show()

# %%
exportData.to_csv('CO2.csv')
